# %%
import os
from glob import glob

files = glob(os.path.join(os.getcwd(), '*.csv'))
len(files)
# Out:
# 2

# %%
import pandas as pd
f1 = files[0]
f2 = files[1]

d1 = pd.read_csv(f1)
d2 = pd.read_csv(f2)

simhash_1 = set(d1['simhash_hex'].tolist())
simhash_2 = set(d2['simhash_hex'].tolist())

len(simhash_2.difference(simhash_1))
# Out:
# 0

# %%
len(simhash_1.difference(simhash_2))
# Out:
# 0
