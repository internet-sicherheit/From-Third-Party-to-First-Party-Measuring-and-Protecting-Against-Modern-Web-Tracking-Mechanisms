# %% [markdown]
# ## 5.2: Total Cookies per Profile
# Browser_ID | Cookies
# -------- | --------
# EU1   | 76,673,629
# EU2   | 76,319,176
# US1   | 83,026,916
# US2   | 99,173,324

# %%
import numpy as np
cookies_per_profile = [76673629, 76319176, 83026916, 99173324]
print(f"[Measurement.Overview.Cookies.5.2] Cookies per profile mean: {np.mean(cookies_per_profile)}, min: {np.min(cookies_per_profile)}, max: {np.max(cookies_per_profile)}, SD: {np.std(cookies_per_profile)}, SUM: {np.sum(cookies_per_profile)}")
# Out:
# [Measurement.Overview.Cookies.5.2] Cookies per profile mean: 83798261.25, min: 76319176, max: 99173324, SD: 9269366.60370657, SUM: 335193045
